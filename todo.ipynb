# %% [markdown]
# <a href="https://colab.research.google.com/github/halfffgod/py_todo/blob/main/todo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

rates = pd.read_csv("todo.csv", sep = ";", usecols = [1,2,3,4,5])
rates.iloc[:, 2] = rates.iloc[:, 2].replace({"y": "yes", "n" : "No"})
rates = rates[rates["price"] != 0.17]

print(rates)

rates.to_csv("todo_new.csv", sep = ";", index = False)
# Out:
#            country  price enable  min_billing_time  billing_step
# 3  IRAN MOBILE MTN  0.119    yes                 1             1
# 4  IRAN MOBILE MTN  0.119    yes                 1             1
